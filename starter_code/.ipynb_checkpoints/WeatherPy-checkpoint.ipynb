# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ## Part I - WeatherPy
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# Your first requirement is to create a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# After each plot add a sentence or too explaining what the code is and analyzing.
#
# Your second requirement is to run linear regression on each relationship, only this time separating them into Northern Hemisphere (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude):
#
# * Northern Hemisphere - Temperature (F) vs. Latitude
# * Southern Hemisphere - Temperature (F) vs. Latitude
# * Northern Hemisphere - Humidity (%) vs. Latitude
# * Southern Hemisphere - Humidity (%) vs. Latitude
# * Northern Hemisphere - Cloudiness (%) vs. Latitude
# * Southern Hemisphere - Cloudiness (%) vs. Latitude
# * Northern Hemisphere - Wind Speed (mph) vs. Latitude
# * Southern Hemisphere - Wind Speed (mph) vs. Latitude
#
# After each pair of plots explain what the linear regression is modeling such as any relationships you notice and any other analysis you may have.
#
# **Optional** You will be creating multiple linear regression plots. To optimize your code, write a function that creates the linear regression plots.
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * Include a print log of each city as it's being processed with the city number and city name.
# * Save a CSV of all retrieved data and a PNG image for each scatter plot.

# %% [markdown]
# ## * For Part I, you must include a written description of three observable trends based on the data.
# * The further away from the equator, the less sunlight that cities received. For that reason, the highest temperature is near the equator and the colder temperatures are in the northern and southern hemispheres.
# * There are less cities around the poles in the highest and lowest latitude because it's colder..
# * Humidity, cloudiness and wind speed have no or very weak correlation towards latitude. Humidity on cities are mainly higher than 60%, wind speed is mainly less than 10 mph and cloudiness is very variable regardless of latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Base URL
base_url = f"{url}appid={weather_api_key}"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %%
# Create a dataframe to view the cities
cities_list={"City Name":cities}
cities_df= pd.DataFrame(cities_list)
cities_df
# Out:
#         City Name
# 0     east london
# 1    kruisfontein
# 2       jamestown
# 3     tuktoyaktuk
# 4          palora
# ..            ...
# 627   salinopolis
# 628           leh
# 629       vendome
# 630      dengzhou
# 631          ayni
#
# [632 rows x 1 columns]

# %% [markdown]
# # Parameters:
# ## message Internal parameter
# ### cod Internal parameter
# * city_id City ID
# * calctime Internal parameter
# #### list
# * dt Time of data calculation, unix, UTC
# * city_name City name
# * lat Geographical coordinates of the location (latitude)
# * lon Geographical coordinates of the location (longitude)
# * dt Time of data calculation, unix, UTC
# * dt_isoDate and time in UTC format
# * timezone Shift in seconds from UTC
# #### main
# * main.temp Temperature, Kelvins
# * main.feels_like Temperature, Kelvins. This temperature parameter accounts for the human perception of weather
# * main.pressure Atmospheric pressure (on the sea level, if there is no sea_level or grnd_level data), hPa
# * main.humidity Humidity, %
# * main.temp_min Minimum temperature within a large city or a megalopolis (optional parameter), Kelvin
# * main.temp_max Maximum temperature within a large city or a megalopolis (optional parameter), Kelvins
# * main.sea_level Atmospheric pressure on the sea level, hPa
# * main.grnd_level Atmospheric pressure on the ground level, hPa
# #### wind
# * wind.speed Wind speed. Unit: meter/sec.
# * wind.deg Wind direction, degrees (meteorological)
# #### clouds
# * clouds.all Cloudiness, %
# #### rain
# * rain.1h Rain volume for the last 1 hour
# * rain.3h Rain volume for the last 3 hours
# #### snow
# * snow.1h Snow volume for the last 1 hour
# * snow.3h Snow volume for the last 3 hours
# #### weather (more info Weather condition codes)
# * weather.id Weather condition id
# * weather.main Group of weather parameters (Rain, Snow, Extreme etc.)
# * weather.description Weather condition within the group
# * weather.icon Weather icon id
# #### weather unit
# * For temperature in Fahrenheit use units=imperial
# * For temperature in Celsius use units=metric
# * Temperature in Kelvin is used by default, no need to use units parameter in API call

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create a list for the weather data
cities_data = []
units="imperial"

# Define variables for count until 50 for each set
count = 0
count_restart = 0
count_increase = 1

# Print the Beginning 
print("Beginning Data Retrieval")
print("------------------------------------------------------------------------------")

# Loop through cities and establish the limit count to 50 with a restart on count and print the result for each increase
for city in cities:
    count = count + 1
    if (count % 50 ==0 and count >= 50):
        count_restart = 0
        count_increase = count_increase + 1
    count_restart = count_restart + 1
    print(f"Processing Record {count_restart} of Set {count_increase} | {city}")
# Query URL
    query_url = f"{base_url}&q={city}&units={units}"
# Use try except inside the loop for error handling    
    try:
        response_cities = requests.get(query_url).json()
# Define the parameters of the response which should include Temperature (F), Humidity (%), Cloudiness (%), Wind Speed (mph) and Latitude
# main.temp_min Minimum temperature within a large city or a megalopolis (optional parameter), Kelvin
# main.temp_max Maximum temperature within a large city or a megalopolis (optional parameter), Kelvins
# main.humidity Humidity, %
# clouds.all Cloudiness, %
# wind.speed Wind speed. Unit: meter/sec.
        country = response_cities["sys"]["country"]
        city_name = response_cities["name"]    
        lat = response_cities["coord"]["lat"]
        lon = response_cities["coord"]["lon"]
        min_temp = response_cities["main"]["temp_min"]
        max_temp = response_cities["main"]["temp_max"]
        humidity = response_cities["main"]["humidity"]
        cloudiness = response_cities["clouds"]["all"]
        wind_speed = response_cities["wind"]["speed"]
        country = response_cities["sys"]["country"]
# Append the data to the list cities data 
        cities_data.append({
            "Country": country,
            "Cities": city_name,
            "Latitude": lat,
            "Longitude": lon,
            "Minimum temperature": min_temp,
            "Maximum temperature": max_temp,
            "Humidity": humidity,
            "Cloudiness": cloudiness,
            "Wind Speed": wind_speed})
    except:
            print(f"City not found. Skipping... {city}")

print("------------------------------------------------------------------------------")
print("Data Retrieval Complete")
print("------------------------------------------------------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------------------------------------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | kruisfontein
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | palora
# Processing Record 6 of Set 1 | komsomolskiy
# Processing Record 7 of Set 1 | baran
# Processing Record 8 of Set 1 | lhokseumawe
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | cururupu
# Processing Record 11 of Set 1 | grand river south east
# City not found. Skipping... grand river south east
# Processing Record 12 of Set 1 | mount isa
# Processing Record 13 of Set 1 | zhigansk
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | ionesti
# Processing Record 17 of Set 1 | alice springs
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | korla
# Processing Record 21 of Set 1 | riberalta
# Processing Record 22 of Set 1 | lata
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | basco
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | lavrentiya
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | amos
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping... belushya guba
# Processing Record 32 of Set 1 | ponta do sol
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | coromandel
# Processing Record 35 of Set 1 | ahuimanu
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | plastun
# Processing Record 38 of Set 1 | sobolevo
# Processing Record 39 of Set 1 | torbay
# Processing Record 40 of Set 1 | lapeer
# Processing Record 41 of Set 1 | atar
# Processing Record 42 of Set 1 | natal
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | touho
# Processing Record 47 of Set 1 | kaitangata
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | cabo san lucas
# Processing Record 1 of Set 2 | vorobyevka
# Processing Record 2 of Set 2 | mayumba
# Processing Record 3 of Set 2 | awbari
# Processing Record 4 of Set 2 | soddy-daisy
# Processing Record 5 of Set 2 | izazi
# Processing Record 6 of Set 2 | kerki
# City not found. Skipping... kerki
# Processing Record 7 of Set 2 | port elizabeth
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | lebu
# Processing Record 11 of Set 2 | loukhi
# Processing Record 12 of Set 2 | port lincoln
# Processing Record 13 of Set 2 | nurota
# Processing Record 14 of Set 2 | porto novo
# Processing Record 15 of Set 2 | miracema do tocantins
# Processing Record 16 of Set 2 | banda aceh
# Processing Record 17 of Set 2 | kupang
# Processing Record 18 of Set 2 | cherskiy
# Processing Record 19 of Set 2 | gbadolite
# Processing Record 20 of Set 2 | killybegs
# Processing Record 21 of Set 2 | karatau
# Processing Record 22 of Set 2 | isla vista
# Processing Record 23 of Set 2 | mehamn
# Processing Record 24 of Set 2 | bathsheba
# Processing Record 25 of Set 2 | dikson
# Processing Record 26 of Set 2 | huarmey
# Processing Record 27 of Set 2 | longlac
# City not found. Skipping... longlac
# Processing Record 28 of Set 2 | juneau
# Processing Record 29 of Set 2 | zapolyarnyy
# Processing Record 30 of Set 2 | nikolskoye
# Processing Record 31 of Set 2 | ahipara
# Processing Record 32 of Set 2 | mys shmidta
# City not found. Skipping... mys shmidta
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping... barentsburg
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | isangel
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | palm coast
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping... taolanaro
# Processing Record 39 of Set 2 | tuatapere
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | atuona
# Processing Record 42 of Set 2 | conceicao do araguaia
# Processing Record 43 of Set 2 | bilibino
# Processing Record 44 of Set 2 | codrington
# Processing Record 45 of Set 2 | souillac
# Processing Record 46 of Set 2 | geraldton
# Processing Record 47 of Set 2 | illoqqortoormiut
# City not found. Skipping... illoqqortoormiut
# Processing Record 48 of Set 2 | kidal
# Processing Record 49 of Set 2 | hermanus
# Processing Record 50 of Set 2 | launceston
# Processing Record 1 of Set 3 | mutis
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | grand gaube
# Processing Record 4 of Set 3 | morgan city
# Processing Record 5 of Set 3 | churapcha
# Processing Record 6 of Set 3 | krasnomayskiy
# Processing Record 7 of Set 3 | umzimvubu
# City not found. Skipping... umzimvubu
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | axim
# Processing Record 10 of Set 3 | esperance
# Processing Record 11 of Set 3 | gigmoto
# Processing Record 12 of Set 3 | dingle
# Processing Record 13 of Set 3 | sabrum
# Processing Record 14 of Set 3 | nanortalik
# Processing Record 15 of Set 3 | kirby
# Processing Record 16 of Set 3 | victoria
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | sentyabrskiy
# City not found. Skipping... sentyabrskiy
# Processing Record 19 of Set 3 | bengkulu
# Processing Record 20 of Set 3 | nouakchott
# Processing Record 21 of Set 3 | mojoagung
# Processing Record 22 of Set 3 | hobart
# Processing Record 23 of Set 3 | karaul
# City not found. Skipping... karaul
# Processing Record 24 of Set 3 | upernavik
# Processing Record 25 of Set 3 | tapaua
# City not found. Skipping... tapaua
# Processing Record 26 of Set 3 | shingu
# Processing Record 27 of Set 3 | starogard gdanski
# Processing Record 28 of Set 3 | kumylzhenskaya
# Processing Record 29 of Set 3 | saskylakh
# Processing Record 30 of Set 3 | yar-sale
# Processing Record 31 of Set 3 | san patricio
# Processing Record 32 of Set 3 | yellowknife
# Processing Record 33 of Set 3 | srednekolymsk
# Processing Record 34 of Set 3 | kirsanov
# Processing Record 35 of Set 3 | tsihombe
# City not found. Skipping... tsihombe
# Processing Record 36 of Set 3 | zamora
# Processing Record 37 of Set 3 | butaritari
# Processing Record 38 of Set 3 | beringovskiy
# Processing Record 39 of Set 3 | airai
# Processing Record 40 of Set 3 | zheleznodorozhnyy
# Processing Record 41 of Set 3 | geresk
# City not found. Skipping... geresk
# Processing Record 42 of Set 3 | x-can
# City not found. Skipping... x-can
# Processing Record 43 of Set 3 | marsh harbour
# Processing Record 44 of Set 3 | mar del plata
# Processing Record 45 of Set 3 | boca do acre
# Processing Record 46 of Set 3 | pitea
# Processing Record 47 of Set 3 | verkhnyaya inta
# Processing Record 48 of Set 3 | sovetskiy
# Processing Record 49 of Set 3 | kavieng
# Processing Record 50 of Set 3 | ust-nera
# Processing Record 1 of Set 4 | high level
# Processing Record 2 of Set 4 | cabadiangan
# Processing Record 3 of Set 4 | warqla
# City not found. Skipping... warqla
# Processing Record 4 of Set 4 | cascais
# Processing Record 5 of Set 4 | sao goncalo do sapucai
# Processing Record 6 of Set 4 | santiago del estero
# Processing Record 7 of Set 4 | laguna
# Processing Record 8 of Set 4 | constitucion
# Processing Record 9 of Set 4 | coquimbo
# Processing Record 10 of Set 4 | matara
# Processing Record 11 of Set 4 | saint-georges
# Processing Record 12 of Set 4 | karamea
# City not found. Skipping... karamea
# Processing Record 13 of Set 4 | sao filipe
# Processing Record 14 of Set 4 | iqaluit
# Processing Record 15 of Set 4 | abu dhabi
# Processing Record 16 of Set 4 | linqiong
# Processing Record 17 of Set 4 | marcona
# City not found. Skipping... marcona
# Processing Record 18 of Set 4 | la sarre
# Processing Record 19 of Set 4 | norman wells
# Processing Record 20 of Set 4 | samusu
# City not found. Skipping... samusu
# Processing Record 21 of Set 4 | san matias
# Processing Record 22 of Set 4 | quirinopolis
# Processing Record 23 of Set 4 | lompoc
# Processing Record 24 of Set 4 | fortuna
# Processing Record 25 of Set 4 | half moon bay
# Processing Record 26 of Set 4 | hofn
# Processing Record 27 of Set 4 | caohai
# Processing Record 28 of Set 4 | kozhva
# Processing Record 29 of Set 4 | nguiu
# City not found. Skipping... nguiu
# Processing Record 30 of Set 4 | ancud
# Processing Record 31 of Set 4 | muroto
# Processing Record 32 of Set 4 | namatanai
# Processing Record 33 of Set 4 | beyneu
# Processing Record 34 of Set 4 | talnakh
# Processing Record 35 of Set 4 | kungurtug
# Processing Record 36 of Set 4 | barra do garcas
# Processing Record 37 of Set 4 | popondetta
# Processing Record 38 of Set 4 | pasighat
# Processing Record 39 of Set 4 | marsabit
# Processing Record 40 of Set 4 | qaanaaq
# Processing Record 41 of Set 4 | thompson
# Processing Record 42 of Set 4 | zhangye
# Processing Record 43 of Set 4 | pevek
# Processing Record 44 of Set 4 | hondo
# Processing Record 45 of Set 4 | haibowan
# City not found. Skipping... haibowan
# Processing Record 46 of Set 4 | khatanga
# Processing Record 47 of Set 4 | aasiaat
# Processing Record 48 of Set 4 | ocampo
# Processing Record 49 of Set 4 | inirida
# Processing Record 50 of Set 4 | hermiston
# Processing Record 1 of Set 5 | rawson
# Processing Record 2 of Set 5 | camacha
# Processing Record 3 of Set 5 | sorland
# Processing Record 4 of Set 5 | nouadhibou
# Processing Record 5 of Set 5 | shimoda
# Processing Record 6 of Set 5 | pangnirtung
# Processing Record 7 of Set 5 | barrow
# Processing Record 8 of Set 5 | leningradskiy
# Processing Record 9 of Set 5 | pacific grove
# Processing Record 10 of Set 5 | sibolga
# Processing Record 11 of Set 5 | nizhneyansk
# City not found. Skipping... nizhneyansk
# Processing Record 12 of Set 5 | ixtapa
# Processing Record 13 of Set 5 | touros
# Processing Record 14 of Set 5 | brae
# Processing Record 15 of Set 5 | san cristobal
# Processing Record 16 of Set 5 | lagoa
# Processing Record 17 of Set 5 | puerto escondido
# Processing Record 18 of Set 5 | tautira
# Processing Record 19 of Set 5 | guerrero negro
# Processing Record 20 of Set 5 | lasa
# Processing Record 21 of Set 5 | mareeba
# Processing Record 22 of Set 5 | manokwari
# Processing Record 23 of Set 5 | darhan
# Processing Record 24 of Set 5 | comodoro rivadavia
# Processing Record 25 of Set 5 | avarua
# Processing Record 26 of Set 5 | severo-kurilsk
# Processing Record 27 of Set 5 | lakselv
# Processing Record 28 of Set 5 | whitianga
# Processing Record 29 of Set 5 | cidreira
# Processing Record 30 of Set 5 | tefe
# Processing Record 31 of Set 5 | yulara
# Processing Record 32 of Set 5 | mezen
# Processing Record 33 of Set 5 | olinda
# Processing Record 34 of Set 5 | coyah
# Processing Record 35 of Set 5 | bonfim
# Processing Record 36 of Set 5 | minsk
# Processing Record 37 of Set 5 | charters towers
# Processing Record 38 of Set 5 | nemuro
# Processing Record 39 of Set 5 | westport
# Processing Record 40 of Set 5 | hefei
# Processing Record 41 of Set 5 | lufilufi
# Processing Record 42 of Set 5 | waddan
# Processing Record 43 of Set 5 | lakatoro
# Processing Record 44 of Set 5 | abiy adi
# City not found. Skipping... abiy adi
# Processing Record 45 of Set 5 | berlevag
# Processing Record 46 of Set 5 | bilma
# Processing Record 47 of Set 5 | bagdarin
# Processing Record 48 of Set 5 | chapais
# Processing Record 49 of Set 5 | bonavista
# Processing Record 50 of Set 5 | arraial do cabo
# Processing Record 1 of Set 6 | el alto
# Processing Record 2 of Set 6 | tezu
# Processing Record 3 of Set 6 | lalomanu
# City not found. Skipping... lalomanu
# Processing Record 4 of Set 6 | robertson
# Processing Record 5 of Set 6 | sawtell
# Processing Record 6 of Set 6 | tilichiki
# Processing Record 7 of Set 6 | vigrestad
# Processing Record 8 of Set 6 | san quintin
# Processing Record 9 of Set 6 | luderitz
# Processing Record 10 of Set 6 | tumannyy
# City not found. Skipping... tumannyy
# Processing Record 11 of Set 6 | yaguajay
# Processing Record 12 of Set 6 | ngunguru
# Processing Record 13 of Set 6 | penzance
# Processing Record 14 of Set 6 | mabaruma
# Processing Record 15 of Set 6 | sibut
# Processing Record 16 of Set 6 | maniitsoq
# Processing Record 17 of Set 6 | dongsheng
# Processing Record 18 of Set 6 | bethel
# Processing Record 19 of Set 6 | birjand
# Processing Record 20 of Set 6 | tiksi
# Processing Record 21 of Set 6 | cedar city
# Processing Record 22 of Set 6 | coxim
# Processing Record 23 of Set 6 | marawi
# Processing Record 24 of Set 6 | kabalo
# Processing Record 25 of Set 6 | saldanha
# Processing Record 26 of Set 6 | ulladulla
# Processing Record 27 of Set 6 | hirara
# Processing Record 28 of Set 6 | sitka
# Processing Record 29 of Set 6 | aklavik
# Processing Record 30 of Set 6 | farmington
# Processing Record 31 of Set 6 | ilulissat
# Processing Record 32 of Set 6 | durango
# Processing Record 33 of Set 6 | amga
# Processing Record 34 of Set 6 | ojiya
# Processing Record 35 of Set 6 | talcahuano
# Processing Record 36 of Set 6 | majene
# Processing Record 37 of Set 6 | mali
# Processing Record 38 of Set 6 | navlya
# Processing Record 39 of Set 6 | yirol
# City not found. Skipping... yirol
# Processing Record 40 of Set 6 | buraydah
# Processing Record 41 of Set 6 | ailigandi
# Processing Record 42 of Set 6 | soyo
# Processing Record 43 of Set 6 | eureka
# Processing Record 44 of Set 6 | porgera
# Processing Record 45 of Set 6 | wilmington
# Processing Record 46 of Set 6 | port-gentil
# Processing Record 47 of Set 6 | rio gallegos
# Processing Record 48 of Set 6 | faanui
# Processing Record 49 of Set 6 | miles city
# Processing Record 50 of Set 6 | wulanhaote
# City not found. Skipping... wulanhaote
# Processing Record 1 of Set 7 | mahebourg
# Processing Record 2 of Set 7 | georgetown
# Processing Record 3 of Set 7 | paamiut
# Processing Record 4 of Set 7 | libreville
# Processing Record 5 of Set 7 | buala
# Processing Record 6 of Set 7 | mocambique
# City not found. Skipping... mocambique
# Processing Record 7 of Set 7 | kiknur
# Processing Record 8 of Set 7 | bambous virieux
# Processing Record 9 of Set 7 | anahuac
# Processing Record 10 of Set 7 | aswan
# Processing Record 11 of Set 7 | sechura
# Processing Record 12 of Set 7 | novoukrainskoye
# Processing Record 13 of Set 7 | north bend
# Processing Record 14 of Set 7 | vila franca do campo
# Processing Record 15 of Set 7 | college
# Processing Record 16 of Set 7 | surdila-gaiseanca
# Processing Record 17 of Set 7 | ostrovnoy
# Processing Record 18 of Set 7 | tura
# Processing Record 19 of Set 7 | ginir
# Processing Record 20 of Set 7 | sistranda
# Processing Record 21 of Set 7 | quang ngai
# Processing Record 22 of Set 7 | loiza
# Processing Record 23 of Set 7 | halalo
# City not found. Skipping... halalo
# Processing Record 24 of Set 7 | san rafael
# Processing Record 25 of Set 7 | umarkot
# Processing Record 26 of Set 7 | carahue
# Processing Record 27 of Set 7 | deputatskiy
# Processing Record 28 of Set 7 | samalaeulu
# City not found. Skipping... samalaeulu
# Processing Record 29 of Set 7 | mata
# Processing Record 30 of Set 7 | edd
# Processing Record 31 of Set 7 | ardistan
# City not found. Skipping... ardistan
# Processing Record 32 of Set 7 | henties bay
# Processing Record 33 of Set 7 | itoman
# Processing Record 34 of Set 7 | saleaula
# City not found. Skipping... saleaula
# Processing Record 35 of Set 7 | aitape
# Processing Record 36 of Set 7 | wamba
# Processing Record 37 of Set 7 | longyearbyen
# Processing Record 38 of Set 7 | qasigiannguit
# Processing Record 39 of Set 7 | falealupo
# City not found. Skipping... falealupo
# Processing Record 40 of Set 7 | koslan
# Processing Record 41 of Set 7 | lamont
# Processing Record 42 of Set 7 | jawar
# Processing Record 43 of Set 7 | planaltina
# Processing Record 44 of Set 7 | hasaki
# Processing Record 45 of Set 7 | borger
# Processing Record 46 of Set 7 | havoysund
# Processing Record 47 of Set 7 | waingapu
# Processing Record 48 of Set 7 | lorengau
# Processing Record 49 of Set 7 | duiwelskloof
# Processing Record 50 of Set 7 | alghero
# Processing Record 1 of Set 8 | voi
# Processing Record 2 of Set 8 | kaduy
# Processing Record 3 of Set 8 | sur
# Processing Record 4 of Set 8 | fort nelson
# Processing Record 5 of Set 8 | taormina
# Processing Record 6 of Set 8 | nenjiang
# Processing Record 7 of Set 8 | massakory
# Processing Record 8 of Set 8 | svetlaya
# Processing Record 9 of Set 8 | ndele
# Processing Record 10 of Set 8 | vila velha
# Processing Record 11 of Set 8 | klaksvik
# Processing Record 12 of Set 8 | anadyr
# Processing Record 13 of Set 8 | iskateley
# Processing Record 14 of Set 8 | marzuq
# Processing Record 15 of Set 8 | saquena
# Processing Record 16 of Set 8 | rawannawi
# City not found. Skipping... rawannawi
# Processing Record 17 of Set 8 | lake cowichan
# Processing Record 18 of Set 8 | gijon
# Processing Record 19 of Set 8 | sibay
# Processing Record 20 of Set 8 | halmstad
# Processing Record 21 of Set 8 | labuhan
# Processing Record 22 of Set 8 | kununurra
# Processing Record 23 of Set 8 | likasi
# Processing Record 24 of Set 8 | hami
# Processing Record 25 of Set 8 | sterling
# Processing Record 26 of Set 8 | cayenne
# Processing Record 27 of Set 8 | prince rupert
# Processing Record 28 of Set 8 | kawalu
# Processing Record 29 of Set 8 | skibbereen
# Processing Record 30 of Set 8 | jalu
# Processing Record 31 of Set 8 | narsaq
# Processing Record 32 of Set 8 | hovd
# Processing Record 33 of Set 8 | wenling
# Processing Record 34 of Set 8 | gogrial
# Processing Record 35 of Set 8 | muros
# Processing Record 36 of Set 8 | varhaug
# Processing Record 37 of Set 8 | sao miguel
# Processing Record 38 of Set 8 | kegayli
# City not found. Skipping... kegayli
# Processing Record 39 of Set 8 | redlands
# Processing Record 40 of Set 8 | mersing
# Processing Record 41 of Set 8 | troitskoye
# Processing Record 42 of Set 8 | port hardy
# Processing Record 43 of Set 8 | trelleborg
# Processing Record 44 of Set 8 | atherton
# Processing Record 45 of Set 8 | kuandian
# Processing Record 46 of Set 8 | sunrise manor
# Processing Record 47 of Set 8 | plerin
# Processing Record 48 of Set 8 | castanos
# Processing Record 49 of Set 8 | khatima
# Processing Record 50 of Set 8 | outlook
# Processing Record 1 of Set 9 | bossangoa
# Processing Record 2 of Set 9 | asau
# Processing Record 3 of Set 9 | matagami
# Processing Record 4 of Set 9 | mwinilunga
# Processing Record 5 of Set 9 | saint george
# Processing Record 6 of Set 9 | sidney
# Processing Record 7 of Set 9 | kafanchan
# Processing Record 8 of Set 9 | vardo
# Processing Record 9 of Set 9 | dhone
# Processing Record 10 of Set 9 | dzhusaly
# City not found. Skipping... dzhusaly
# Processing Record 11 of Set 9 | hanko
# Processing Record 12 of Set 9 | san vicente
# Processing Record 13 of Set 9 | cockburn town
# Processing Record 14 of Set 9 | panzhihua
# Processing Record 15 of Set 9 | temaraia
# City not found. Skipping... temaraia
# Processing Record 16 of Set 9 | rocha
# Processing Record 17 of Set 9 | powell river
# Processing Record 18 of Set 9 | pineville
# Processing Record 19 of Set 9 | moron
# Processing Record 20 of Set 9 | muscat
# Processing Record 21 of Set 9 | glenwood springs
# Processing Record 22 of Set 9 | homer
# Processing Record 23 of Set 9 | eldorado
# Processing Record 24 of Set 9 | remontnoye
# Processing Record 25 of Set 9 | belyy yar
# Processing Record 26 of Set 9 | korcula
# Processing Record 27 of Set 9 | annamalainagar
# Processing Record 28 of Set 9 | angoche
# Processing Record 29 of Set 9 | bridlington
# Processing Record 30 of Set 9 | chatellerault
# Processing Record 31 of Set 9 | san pedro
# Processing Record 32 of Set 9 | meyungs
# City not found. Skipping... meyungs
# Processing Record 33 of Set 9 | pisco
# Processing Record 34 of Set 9 | tasbuget
# City not found. Skipping... tasbuget
# Processing Record 35 of Set 9 | riohacha
# Processing Record 36 of Set 9 | namibe
# Processing Record 37 of Set 9 | araouane
# Processing Record 38 of Set 9 | imbituba
# Processing Record 39 of Set 9 | saint-joseph
# Processing Record 40 of Set 9 | hualmay
# Processing Record 41 of Set 9 | erdenet
# Processing Record 42 of Set 9 | sorvag
# City not found. Skipping... sorvag
# Processing Record 43 of Set 9 | yichang
# Processing Record 44 of Set 9 | vao
# Processing Record 45 of Set 9 | emerald
# Processing Record 46 of Set 9 | tim
# Processing Record 47 of Set 9 | rungata
# City not found. Skipping... rungata
# Processing Record 48 of Set 9 | amderma
# City not found. Skipping... amderma
# Processing Record 49 of Set 9 | midleton
# Processing Record 50 of Set 9 | flin flon
# Processing Record 1 of Set 10 | kachug
# Processing Record 2 of Set 10 | vaitupu
# City not found. Skipping... vaitupu
# Processing Record 3 of Set 10 | elko
# Processing Record 4 of Set 10 | mizdah
# Processing Record 5 of Set 10 | vestmannaeyjar
# Processing Record 6 of Set 10 | menongue
# Processing Record 7 of Set 10 | katsuura
# Processing Record 8 of Set 10 | margate
# Processing Record 9 of Set 10 | lanzhou
# Processing Record 10 of Set 10 | shirvan
# Processing Record 11 of Set 10 | saint anthony
# Processing Record 12 of Set 10 | blue springs
# Processing Record 13 of Set 10 | kulhudhuffushi
# Processing Record 14 of Set 10 | sibiti
# Processing Record 15 of Set 10 | najran
# Processing Record 16 of Set 10 | lazarev
# Processing Record 17 of Set 10 | derzhavinsk
# Processing Record 18 of Set 10 | andenes
# Processing Record 19 of Set 10 | limbe
# Processing Record 20 of Set 10 | bentiu
# Processing Record 21 of Set 10 | surt
# Processing Record 22 of Set 10 | banfora
# Processing Record 23 of Set 10 | kloulklubed
# Processing Record 24 of Set 10 | kahului
# Processing Record 25 of Set 10 | franklin
# Processing Record 26 of Set 10 | kamenka
# Processing Record 27 of Set 10 | moerai
# Processing Record 28 of Set 10 | iyo
# Processing Record 29 of Set 10 | clarence town
# Processing Record 30 of Set 10 | swan hill
# Processing Record 31 of Set 10 | tabuk
# Processing Record 32 of Set 10 | keti bandar
# Processing Record 33 of Set 10 | turbat
# Processing Record 34 of Set 10 | shitanjing
# Processing Record 35 of Set 10 | meulaboh
# Processing Record 36 of Set 10 | sassenheim
# Processing Record 37 of Set 10 | mesyagutovo
# Processing Record 38 of Set 10 | attawapiskat
# City not found. Skipping... attawapiskat
# Processing Record 39 of Set 10 | nelson bay
# Processing Record 40 of Set 10 | bac lieu
# Processing Record 41 of Set 10 | coolum beach
# Processing Record 42 of Set 10 | humberto de campos
# Processing Record 43 of Set 10 | mogadishu
# Processing Record 44 of Set 10 | genhe
# Processing Record 45 of Set 10 | kiama
# Processing Record 46 of Set 10 | jacareacanga
# Processing Record 47 of Set 10 | itupeva
# Processing Record 48 of Set 10 | egvekinot
# Processing Record 49 of Set 10 | tsabong
# Processing Record 50 of Set 10 | chuy
# Processing Record 1 of Set 11 | tres passos
# Processing Record 2 of Set 11 | sosnovo-ozerskoye
# Processing Record 3 of Set 11 | sault sainte marie
# Processing Record 4 of Set 11 | dwarka
# Processing Record 5 of Set 11 | payo
# Processing Record 6 of Set 11 | nome
# Processing Record 7 of Set 11 | ballina
# Processing Record 8 of Set 11 | yumen
# Processing Record 9 of Set 11 | honiara
# Processing Record 10 of Set 11 | breves
# Processing Record 11 of Set 11 | ubinskoye
# Processing Record 12 of Set 11 | suntar
# Processing Record 13 of Set 11 | one hundred mile house
# City not found. Skipping... one hundred mile house
# Processing Record 14 of Set 11 | vaitape
# Processing Record 15 of Set 11 | alofi
# Processing Record 16 of Set 11 | oranjemund
# Processing Record 17 of Set 11 | seduva
# Processing Record 18 of Set 11 | umm lajj
# Processing Record 19 of Set 11 | avera
# Processing Record 20 of Set 11 | santa maria
# Processing Record 21 of Set 11 | zemaiciu naumiestis
# Processing Record 22 of Set 11 | adrar
# Processing Record 23 of Set 11 | inhambane
# Processing Record 24 of Set 11 | tazovskiy
# Processing Record 25 of Set 11 | sakaiminato
# Processing Record 26 of Set 11 | ranong
# Processing Record 27 of Set 11 | george
# Processing Record 28 of Set 11 | sakakah
# Processing Record 29 of Set 11 | gat
# Processing Record 30 of Set 11 | necochea
# Processing Record 31 of Set 11 | skagen
# Processing Record 32 of Set 11 | xiongyue
# Processing Record 33 of Set 11 | aktash
# Processing Record 34 of Set 11 | kiyasovo
# Processing Record 35 of Set 11 | kampot
# Processing Record 36 of Set 11 | sisimiut
# Processing Record 37 of Set 11 | inongo
# Processing Record 38 of Set 11 | listica
# City not found. Skipping... listica
# Processing Record 39 of Set 11 | karaj
# Processing Record 40 of Set 11 | qunduz
# Processing Record 41 of Set 11 | argir
# Processing Record 42 of Set 11 | moyobamba
# Processing Record 43 of Set 11 | pointe michel
# Processing Record 44 of Set 11 | lochgilphead
# Processing Record 45 of Set 11 | latung
# Processing Record 46 of Set 11 | ramtek
# Processing Record 47 of Set 11 | sokolo
# Processing Record 48 of Set 11 | rio claro
# Processing Record 49 of Set 11 | dunedin
# Processing Record 50 of Set 11 | dolbeau
# City not found. Skipping... dolbeau
# Processing Record 1 of Set 12 | banjar
# Processing Record 2 of Set 12 | arman
# Processing Record 3 of Set 12 | guaruja
# Processing Record 4 of Set 12 | exeter
# Processing Record 5 of Set 12 | kulob
# Processing Record 6 of Set 12 | san jose
# Processing Record 7 of Set 12 | kavaratti
# Processing Record 8 of Set 12 | tuggurt
# City not found. Skipping... tuggurt
# Processing Record 9 of Set 12 | lolua
# City not found. Skipping... lolua
# Processing Record 10 of Set 12 | luorong
# Processing Record 11 of Set 12 | tabou
# Processing Record 12 of Set 12 | scottsbluff
# Processing Record 13 of Set 12 | bonito
# Processing Record 14 of Set 12 | alta floresta
# Processing Record 15 of Set 12 | alamogordo
# Processing Record 16 of Set 12 | portland
# Processing Record 17 of Set 12 | hameenlinna
# Processing Record 18 of Set 12 | acajutla
# Processing Record 19 of Set 12 | karamay
# City not found. Skipping... karamay
# Processing Record 20 of Set 12 | yarmouth
# Processing Record 21 of Set 12 | shirokiy
# Processing Record 22 of Set 12 | ramsar
# Processing Record 23 of Set 12 | zhezkazgan
# Processing Record 24 of Set 12 | karla
# Processing Record 25 of Set 12 | tulsipur
# Processing Record 26 of Set 12 | vila
# Processing Record 27 of Set 12 | ambon
# Processing Record 28 of Set 12 | ugoofaaru
# Processing Record 29 of Set 12 | chake chake
# Processing Record 30 of Set 12 | jiuquan
# Processing Record 31 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 12 | medford
# Processing Record 33 of Set 12 | bokoro
# Processing Record 34 of Set 12 | gemena
# Processing Record 35 of Set 12 | guichicovi
# City not found. Skipping... guichicovi
# Processing Record 36 of Set 12 | paramonga
# Processing Record 37 of Set 12 | senador jose porfirio
# Processing Record 38 of Set 12 | tual
# Processing Record 39 of Set 12 | yerbogachen
# Processing Record 40 of Set 12 | cabedelo
# Processing Record 41 of Set 12 | saint-augustin
# Processing Record 42 of Set 12 | bonthe
# Processing Record 43 of Set 12 | tomohon
# Processing Record 44 of Set 12 | lexington
# Processing Record 45 of Set 12 | kimbe
# Processing Record 46 of Set 12 | mailsi
# Processing Record 47 of Set 12 | methoni
# Processing Record 48 of Set 12 | wakkanai
# Processing Record 49 of Set 12 | maragogi
# Processing Record 50 of Set 12 | vanimo
# Processing Record 1 of Set 13 | itapirapua
# Processing Record 2 of Set 13 | kinshasa
# Processing Record 3 of Set 13 | makakilo city
# Processing Record 4 of Set 13 | napier
# Processing Record 5 of Set 13 | sioux city
# Processing Record 6 of Set 13 | concepcion del uruguay
# Processing Record 7 of Set 13 | aldan
# Processing Record 8 of Set 13 | kaeo
# Processing Record 9 of Set 13 | kinsale
# Processing Record 10 of Set 13 | den helder
# Processing Record 11 of Set 13 | manzil kamil
# Processing Record 12 of Set 13 | yaan
# Processing Record 13 of Set 13 | neryungri
# Processing Record 14 of Set 13 | tumpat
# Processing Record 15 of Set 13 | itapuranga
# Processing Record 16 of Set 13 | alto araguaia
# Processing Record 17 of Set 13 | polyarnyy
# Processing Record 18 of Set 13 | chipinge
# Processing Record 19 of Set 13 | san vicente de canete
# Processing Record 20 of Set 13 | almaznyy
# Processing Record 21 of Set 13 | mehran
# Processing Record 22 of Set 13 | palabuhanratu
# City not found. Skipping... palabuhanratu
# Processing Record 23 of Set 13 | bogorodsk
# Processing Record 24 of Set 13 | penapolis
# Processing Record 25 of Set 13 | collierville
# Processing Record 26 of Set 13 | great falls
# Processing Record 27 of Set 13 | sataua
# City not found. Skipping... sataua
# Processing Record 28 of Set 13 | melnikovo
# Processing Record 29 of Set 13 | salinopolis
# Processing Record 30 of Set 13 | leh
# Processing Record 31 of Set 13 | vendome
# Processing Record 32 of Set 13 | dengzhou
# Processing Record 33 of Set 13 | ayni
# ------------------------------------------------------------------------------
# Data Retrieval Complete
# ------------------------------------------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_data_df = pd.DataFrame(cities_data)
cities_data_df.head()
# Out:
#   Country        Cities  Latitude  Longitude  Minimum temperature  \
# 0      ZA   East London    -33.02      27.91                76.23
# 1      ZA  Kruisfontein    -34.00      24.73                60.22
# 2      US     Jamestown     42.10     -79.24                57.20
# 3      CA   Tuktoyaktuk     69.45    -133.04                 6.80
# 4      EC        Palora     -1.70     -77.93                71.60
#
#    Maximum temperature  Humidity  Cloudiness  Wind Speed
# 0                76.23        38           0        5.26
# 1                60.22        69           1       10.02
# 2                57.20        50          75       16.11
# 3                 6.80        92          40       12.75
# 4                71.60        94          90        2.24

# %%
cities_data_df.count()
# Out:
# Country                579
# Cities                 579
# Latitude               579
# Longitude              579
# Minimum temperature    579
# Maximum temperature    579
# Humidity               579
# Cloudiness             579
# Wind Speed             579
# dtype: int64

# %%
# Saving the dataframe as a csv file
cities_data_df.to_csv("Cities weather worldwide.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Scatter plot the data with Matplotlib 
cities_latitude = cities_data_df["Latitude"]
cities_maximum_temperature = cities_data_df["Maximum temperature"]
correlation = st.pearsonr(cities_latitude, cities_maximum_temperature)
cities_data_df.plot(kind="scatter", x="Latitude", y="Maximum temperature",marker="o",color="tab:blue",s=50,figsize=(20,7),grid=True)
plt.xlabel("Latitude",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.ylabel("Max Temperature (F)",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.title("City Latitude vs. Max Temperature",fontsize=30,fontweight="semibold", family="Times New Roman",color="orange")
plt.savefig("latitudevstemperature.png") 
plt.show()
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is -0.54

# %% [markdown]
# ### * Cities from the sample that are closer to the equator are warmer, the temperature rises in cities while approaching to the equator.
# ### * Cities from the sample in the north and south are colder, the temperature decreases in cities while approaching to the north and south.
# ### * There is none correlation between both factors.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Scatter plot the data with Matplotlib 
cities_humidity = cities_data_df["Humidity"]
correlation = st.pearsonr(cities_latitude, cities_humidity)
cities_data_df.plot(kind="scatter", x="Latitude", y="Humidity",marker="o",color="tab:blue",s=50,figsize=(20,7),grid=True)
plt.xlabel("Latitude",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.ylabel("Humidity (%)",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.title("City Latitude vs. Humidity",fontsize=30,fontweight="semibold", family="Times New Roman",color="orange")
plt.savefig("latitudevshumidity.png") 
plt.show()
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.07

# %% [markdown]
# ### * Cities from the sample have high humidity percentage regardless of its latitude.
# ### * There is very weak correlation between both factors.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Scatter plot the data with Matplotlib 
cities_cloudiness = cities_data_df["Cloudiness"]
correlation = st.pearsonr(cities_latitude, cities_cloudiness)
cities_data_df.plot(kind="scatter", x="Latitude", y="Cloudiness",marker="o",color="tab:blue",s=50,figsize=(20,7),grid=True)
plt.xlabel("Latitude",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.ylabel("Cloudiness (%)",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.title("City Latitude vs. Cloudiness",fontsize=30,fontweight="semibold", family="Times New Roman",color="orange")
plt.savefig("latitudevscloudiness.png") 
plt.show()
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.15

# %% [markdown]
# ### * Cities from the sample are mainly cloudy regardless of its latitude.
# ### * There is very weak correlation between both factors.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Scatter plot the data with Matplotlib 
cities_windspeed = cities_data_df["Wind Speed"]
correlation = st.pearsonr(cities_latitude, cities_windspeed)
cities_data_df.plot(kind="scatter", x="Latitude", y="Wind Speed",marker="o",color="tab:blue",s=50,figsize=(20,7),grid=True)
plt.xlabel("Latitude",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.ylabel("Wind Speed (mph)",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.title("City Latitude vs. Wind Speed",fontsize=30,fontweight="semibold", family="Times New Roman",color="orange")
plt.savefig("latitudevswindspeed.png") 
plt.show()
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.03

# %%
round(cities_windspeed.mean(),0)
# Out:
# 8.0

# %% [markdown]
# ### * Cities from the sample have an average wind speed around 8 mph regardless of its latitude.
# ### * There is none correlation between both factors.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# Create Northern and Southern Hemisphere DataFrames
# Plot the linear regression model on top of the previous scatter plot.

# %%
cities_data_North_df=cities_data_df.loc[cities_data_df["Latitude"] > 0]
cities_data_North_df.head()
# Out:
#   Country           Cities  Latitude  Longitude  Minimum temperature  \
# 2      US        Jamestown     42.10     -79.24                57.20
# 3      CA      Tuktoyaktuk     69.45    -133.04                 6.80
# 5      UZ  Yangi Marg`ilon     40.43      71.72                69.80
# 6      IN            Bārān     25.10      76.52                92.66
# 7      ID      Lhokseumawe      5.18      97.15                78.84
#
#    Maximum temperature  Humidity  Cloudiness  Wind Speed
# 2                57.20        50          75       16.11
# 3                 6.80        92          40       12.75
# 5                69.80        43          40       23.04
# 6                92.66        11           0        4.94
# 7                78.84        85         100        3.18

# %%
cities_data_South_df=cities_data_df.loc[cities_data_df["Latitude"] < 0]
cities_data_South_df.head()
# Out:
#   Country        Cities  Latitude  Longitude  Minimum temperature  \
# 0      ZA   East London    -33.02      27.91                76.23
# 1      ZA  Kruisfontein    -34.00      24.73                60.22
# 4      EC        Palora     -1.70     -77.93                71.60
# 8      CL  Punta Arenas    -53.15     -70.92                48.00
# 9      BR      Cururupu     -1.83     -44.87                89.01
#
#    Maximum temperature  Humidity  Cloudiness  Wind Speed
# 0                76.23        38           0        5.26
# 1                60.22        69           1       10.02
# 4                71.60        94          90        2.24
# 8                48.20        87          75       10.29
# 9                89.01        57          19        6.49

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_cities_latitude = cities_data_North_df["Latitude"]
north_cities_maximum_temperature = cities_data_North_df["Maximum temperature"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_cities_latitude, north_cities_maximum_temperature)
regress_values = north_cities_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
cities_data_North_df.plot(kind="scatter", x="Latitude", y="Maximum temperature",marker="o",color="tab:blue",s=50,figsize=(20,7),grid=True)
plt.plot(north_cities_latitude,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="tab:red")
plt.title(f"Correlation between latitude and maximum temperature on Northern Hemisphere",fontsize=30,fontweight="semibold", color="orange", family="Times New Roman")
plt.xlabel("Latitude",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.ylabel("Max Temperature (F)",style="italic",family="Times New Roman",fontsize=20,color="orange")
print(f"The r-squared is: {round(rvalue,2)}")
print(f"The equation of the regression line is: {line_eq}")
plt.savefig("northlatitudevstemperature.png") 
plt.show()
# Out:
# The r-squared is: -0.88
# The equation of the regression line is: y = -0.97x + 99.64

# %%
north_cities_maximum_temperature.min()
# Out:
# 1.89

# %% [markdown]
# ### * Cities from the sample in the north are colder, the temperature decreases in cities while approaching to the north.
# ### * The city in the north with the colder temperature has 2 Farenheith degrees.
# ### * There is none correlation between both factors.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_cities_latitude = cities_data_South_df["Latitude"]
south_cities_maximum_temperature = cities_data_South_df["Maximum temperature"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_cities_latitude, south_cities_maximum_temperature)
regress_values = south_cities_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
cities_data_South_df.plot(kind="scatter", x="Latitude", y="Maximum temperature",marker="o",color="tab:blue",s=50,figsize=(20,7),grid=True)
plt.plot(south_cities_latitude,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="tab:red")
plt.title(f"Correlation between latitude and maximum temperature on South Hemisphere",fontsize=30,fontweight="semibold", color="orange", family="Times New Roman")
plt.xlabel("Latitude",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.ylabel("Max Temperature (F)",style="italic",family="Times New Roman",fontsize=20,color="orange")
print(f"The r-squared is: {round(rvalue,2)}")
print(f"The equation of the regression line is: {line_eq}")
plt.savefig("southlatitudevstemperature.png") 
plt.show()
# Out:
# The r-squared is: 0.73
# The equation of the regression line is: y = 0.66x + 85.13

# %%
south_cities_maximum_temperature.min()
# Out:
# 40.89

# %% [markdown]
# ### * Cities from the sample in the south are colder, the temperature decreases in cities while approaching to the and south.
# ### * The city in the south with the colder temperature has 41 Farenheith degrees.
# ### * There is a strong correlation between both factors.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_cities_humidity = cities_data_North_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_cities_latitude, north_cities_humidity)
regress_values = north_cities_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
cities_data_North_df.plot(kind="scatter", x="Latitude", y="Humidity",marker="o",color="tab:blue",s=50,figsize=(20,7),grid=True)
plt.plot(north_cities_latitude,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="tab:red")
plt.title(f"Correlation between latitude and humidity on Northern Hemisphere",fontsize=30,fontweight="semibold", color="orange", family="Times New Roman")
plt.xlabel("Latitude",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.ylabel("Humidity (%)",style="italic",family="Times New Roman",fontsize=20,color="orange")
print(f"The r-squared is: {round(rvalue,2)}")
print(f"The equation of the regression line is: {line_eq}")
plt.savefig("northlatitudevshumidity.png") 
plt.show()
# Out:
# The r-squared is: 0.29
# The equation of the regression line is: y = 0.35x + 50.34

# %% [markdown]
# ### * Cities from the sample have high humidity percentage in the north.
# ### * There is a very weak correlation between both factors.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_cities_humidity = cities_data_South_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_cities_latitude, south_cities_humidity)
regress_values = south_cities_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
cities_data_South_df.plot(kind="scatter", x="Latitude", y="Humidity",marker="o",color="tab:blue",s=50,figsize=(20,7),grid=True)
plt.plot(south_cities_latitude,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="tab:red")
plt.title(f"Correlation between latitude and humidity on South Hemisphere",fontsize=30,fontweight="semibold", color="orange", family="Times New Roman")
plt.xlabel("Latitude",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.ylabel("Humidity (%)",style="italic",family="Times New Roman",fontsize=20,color="orange")
print(f"The r-squared is: {round(rvalue,2)}")
print(f"The equation of the regression line is: {line_eq}")
plt.savefig("southlatitudevshumidity.png") 
plt.show()
# Out:
# The r-squared is: 0.06
# The equation of the regression line is: y = 0.08x + 69.29

# %% [markdown]
# ### * Cities from the sample have high humidity percentage in the south.
# ### * There is a very weak correlation between both factors.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_cities_cloudiness = cities_data_North_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_cities_latitude, north_cities_cloudiness)
regress_values = north_cities_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
cities_data_North_df.plot(kind="scatter", x="Latitude", y="Cloudiness",marker="o",color="tab:blue",s=50,figsize=(20,7),grid=True)
plt.plot(north_cities_latitude,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="tab:red")
plt.title(f"Correlation between latitude and cloudiness on Northern Hemisphere",fontsize=30,fontweight="semibold", color="orange", family="Times New Roman")
plt.xlabel("Latitude",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.ylabel("Cloudiness (%)",style="italic",family="Times New Roman",fontsize=20,color="orange")
print(f"The r-squared is: {round(rvalue,2)}")
print(f"The equation of the regression line is: {line_eq}")
plt.savefig("northlatitudevscloudiness.png") 
plt.show()
# Out:
# The r-squared is: 0.11
# The equation of the regression line is: y = 0.22x + 41.98

# %% [markdown]
# ### * Cities from the sample are mainly cloudy in the north.
# ### * There is a very weak correlation between both factors.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_cities_cloudiness = cities_data_South_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_cities_latitude, south_cities_cloudiness)
regress_values = south_cities_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
cities_data_South_df.plot(kind="scatter", x="Latitude", y="Cloudiness",marker="o",color="tab:blue",s=50,figsize=(20,7),grid=True)
plt.plot(south_cities_latitude,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="tab:red")
plt.title(f"Correlation between latitude and cloudiness on South Hemisphere",fontsize=30,fontweight="semibold", color="orange", family="Times New Roman")
plt.xlabel("Latitude",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.ylabel("Cloudiness (%)",style="italic",family="Times New Roman",fontsize=20,color="orange")
print(f"The r-squared is: {round(rvalue,2)}")
print(f"The equation of the regression line is: {line_eq}")
plt.savefig("southlatitudevscloudiness.png") 
plt.show()
# Out:
# The r-squared is: 0.17
# The equation of the regression line is: y = 0.44x + 51.47

# %% [markdown]
# ### * Cities from the sample are mainly cloudy in the south.
# ### * There is a very weak correlation between both factors.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_cities_windspeed = cities_data_North_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_cities_latitude, north_cities_windspeed)
regress_values = north_cities_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
cities_data_North_df.plot(kind="scatter", x="Latitude", y="Wind Speed",marker="o",color="tab:blue",s=50,figsize=(20,7),grid=True)
plt.plot(north_cities_latitude,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="tab:red")
plt.title(f"Correlation between latitude and wind speed on Northern Hemisphere",fontsize=30,fontweight="semibold", color="orange", family="Times New Roman")
plt.xlabel("Latitude",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.ylabel("Wind Speed (mph)",style="italic",family="Times New Roman",fontsize=20,color="orange")
print(f"The r-squared is: {round(rvalue,2)}")
print(f"The equation of the regression line is: {line_eq}")
plt.savefig("northlatitudevswindspeed.png") 
plt.show()
# Out:
# The r-squared is: 0.02
# The equation of the regression line is: y = 0.01x + 7.89

# %%
round(north_cities_windspeed.mean(),0)
# Out:
# 8.0

# %% [markdown]
# ### * Cities from the sample have an average wind speed around 4 mph in the north.
# ### * There is none correlation between both factors.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_cities_windspeed = cities_data_South_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_cities_latitude, south_cities_windspeed)
regress_values = south_cities_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
cities_data_South_df.plot(kind="scatter", x="Latitude", y="Wind Speed",marker="o",color="tab:blue",s=50,figsize=(20,7),grid=True)
plt.plot(south_cities_latitude,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="tab:red")
plt.title(f"Correlation between latitude and wind speed on South Hemisphere",fontsize=30,fontweight="semibold", color="orange", family="Times New Roman")
plt.xlabel("Latitude",style="italic",family="Times New Roman",fontsize=20,color="orange")
plt.ylabel("Wind Speed (mph)",style="italic",family="Times New Roman",fontsize=20,color="orange")
print(f"The r-squared is: {round(rvalue,2)}")
print(f"The equation of the regression line is: {line_eq}")
plt.savefig("southlatitudevswindspeed.png") 
plt.show()
# Out:
# The r-squared is: -0.17
# The equation of the regression line is: y = -0.05x + 6.52

# %%
round(south_cities_windspeed.mean(),0)
# Out:
# 8.0

# %% [markdown]
# ### * Cities from the sample have an average wind speed around 4 mph in the south.
# ### * There is none correlation between both factors.
